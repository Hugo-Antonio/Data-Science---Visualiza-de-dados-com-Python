# %% [markdown]
# <a href="https://colab.research.google.com/github/Hugo-Antonio/Data-Science---Visualiza-o-de-dados-com-Python/blob/master/Aula%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt 
x = [1,2]
y = [3,4]
plt.plot(x, y)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import matplotlib.pyplot as plt 
x = [1,5]
y = [2,3]
plt.plot(x, y)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import matplotlib.pyplot as plt
x = [1,2,5]
y = [2,3,7]
plt.title("Meu primeiro grafico em Python")
plt.xlabel("Eixo x")
plt.ylabel("Eixo y")
plt.plot (x,y)
plt.show()
